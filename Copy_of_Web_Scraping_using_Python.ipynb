# %% [markdown]
# <a href="https://colab.research.google.com/github/LokeCoder11/KnowledgeReference/blob/main/Copy_of_Web_Scraping_using_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Topics
# 1. Beautiful Soup : Find_all with Sample HTML
# 2. Scraping Table From the web :https://www.loc.gov/standards/iso639-2/php/code_list.php
# 3. Scraping Movie URL's, Movie Title, release Year,Genres,IMBD,Runtime/Duration,Age Rating,Production Countries,Streaming Service From the web : https://www.justwatch.com/in/movies?release_year_from=2013
# 4. File management command in python

# %%
#Installing all necessary labraries
# !pip install bs4
# !pip install requests

# %%
#import all necessary labraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %% [markdown]
# ### Beautiful Soup : Find_all with Sample HTML

# %%
html_doc = '''
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Sample HTML Document</title>
    <style>
        .container {
            max-width: 800px;
            margin: 0 auto;
            padding: 20px;
            border: 1px solid #ccc;
        }
        .button {
            display: inline-block;
            padding: 10px 20px;
            background-color: #007bff;
            color: #fff;
            text-decoration: none;
            border-radius: 5px;
        }
    </style>
</head>
<body>
    <header class="container">
        <h1>Welcome to My Website</h1>
        <nav>
            <ul>
                <li><a href="#">Home</a></li>
                <li><a href="#">About</a></li>
                <li><a href="#">Services</a></li>
                <li><a href="#">Contact</a></li>
            </ul>
        </nav>
    </header>

    <main class="container">
        <section>
            <h2>About Us</h2>
            <p>Lorem ipsum dolor sit amet, consectetur adipiscing elit. Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.</p>
        </section>

        <section>
            <h2>Our Services</h2>
            <ul>
                <li>Service 1</li>
                <li>Service 2</li>
                <li>Service 3</li>
            </ul>
        </section>

        <section>
            <h2>Featured Products</h2>
            <div class="product-container">
                <div class="product" data-product-id="123">
                    <img src="product1.jpg" alt="Product 1">
                    <h3>Product 1</h3>
                    <p>$19.99</p>
                    <a href="#" class="button">Add to Cart</a>
                </div>
                <div class="product" data-product-id="456">
                    <img src="product2.jpg" alt="Product 2">
                    <h3>Product 2</h3>
                    <p>$24.99</p>
                    <a href="#" class="button">Add to Cart</a>
                </div>
            </div>
        </section>

        <section>
            <h2>Contact Us</h2>
            <form class="contact-form">
                <label for="name">Name:Alok</label>
                <input type="text" id="name" name="name">
                <label for="email">Email:</label>
                <input type="email" id="email" name="email">
                <label for="message">Message:</label>
                <textarea id="message" name="message"></textarea>
                <button type="submit" class="button">Send Message</button>
            </form>
        </section>

        <section>
            <h2>Related Links</h2>
            <ul>
                <li><a href="#" target="_blank">Link 1</a></li>
                <li><a href="#" target="_blank">Link 2</a></li>
                <li><a href="#" target="_blank">Link 3</a></li>
            </ul>
        </section>

        <section>
            <h2>Latest News</h2>
            <table class="news-table">
                <thead>
                    <tr>
                        <th>Date</th>
                        <th>Title</th>
                        <th>Category</th>
                    </tr>
                </thead>
                <tbody>
                    <tr>
                        <td>2024-05-01</td>
                        <td>News 1</td>
                        <td>General</td>
                    </tr>
                    <tr>
                        <td>2024-05-02</td>
                        <td>News 2</td>
                        <td>Technology</td>
                    </tr>
                </tbody>
            </table>
        </section>

        <section>
            <h2>Company Location</h2>
            <div class="map">
                <img src="map.jpg" alt="Map">
            </div>
        </section>
    </main>

    <footer class="container">
        <p>&copy; 2024 My Website. All rights reserved.</p>
    </footer>
</body>
</html>

'''

# %%
soup=BeautifulSoup(html_doc,'html.parser')
# Printing the prettified HTML content
# print(soup.prettify())

# %%
# Objective : Get the about us : text
soup.find_all('main', attrs = {'class': 'container'})
# Out:
# [<main class="container">
#  <section>
#  <h2>About Us</h2>
#  <p>Lorem ipsum dolor sit amet, consectetur adipiscing elit. Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.</p>
#  </section>
#  <section>
#  <h2>Our Services</h2>
#  <ul>
#  <li>Service 1</li>
#  <li>Service 2</li>
#  <li>Service 3</li>
#  </ul>
#  </section>
#  <section>
#  <h2>Featured Products</h2>
#  <div class="product-container">
#  <div class="product" data-product-id="123">
#  <img alt="Product 1" src="product1.jpg"/>
#  <h3>Product 1</h3>
#  <p>$19.99</p>
#  <a class="button" href="#">Add to Cart</a>
#  </div>
#  <div class="product" data-product-id="456">
#  <img alt="Product 2" src="product2.jpg"/>
#  <h3>Product 2</h3>
#  <p>$24.99</p>
#  <a class="button" href="#">Add to Cart</a>
#  </div>
#  </div>
#  </section>
#  <section>
#  <h2>Contact Us</h2>
#  <form class="contact-form">
#  <label for="name">Name:Alok</label>
#  <input id="name" name="name" type="text"/>
# ...

# %%
soup.find_all('main', attrs = {'class': 'container'})[0].find_all('section')
# Out:
# [<section>
#  <h2>About Us</h2>
#  <p>Lorem ipsum dolor sit amet, consectetur adipiscing elit. Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.</p>
#  </section>,
#  <section>
#  <h2>Our Services</h2>
#  <ul>
#  <li>Service 1</li>
#  <li>Service 2</li>
#  <li>Service 3</li>
#  </ul>
#  </section>,
#  <section>
#  <h2>Featured Products</h2>
#  <div class="product-container">
#  <div class="product" data-product-id="123">
#  <img alt="Product 1" src="product1.jpg"/>
#  <h3>Product 1</h3>
#  <p>$19.99</p>
#  <a class="button" href="#">Add to Cart</a>
#  </div>
#  <div class="product" data-product-id="456">
#  <img alt="Product 2" src="product2.jpg"/>
#  <h3>Product 2</h3>
#  <p>$24.99</p>
#  <a class="button" href="#">Add to Cart</a>
#  </div>
#  </div>
#  </section>,
#  <section>
#  <h2>Contact Us</h2>
#  <form class="contact-form">
#  <label for="name">Name:Alok</label>
#  <input id="name" name="name" type="text"/>
#  <label for="email">Email:</label>
# ...

# %%
soup.find_all('main', attrs = {'class': 'container'})[0].find_all('section')[0].find_all('p')
# Out:
# [<p>Lorem ipsum dolor sit amet, consectetur adipiscing elit. Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.</p>]

# %%
soup.find_all('main', attrs = {'class': 'container'})[0].find_all('section')[0].find_all('p')[0].text
# Out:
# 'Lorem ipsum dolor sit amet, consectetur adipiscing elit. Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.'

# %%
# Objective : Get the map data
soup.find_all('div', attrs = {'class':'map'})
# Out:
# [<div class="map">
#  <img alt="Map" src="map.jpg"/>
#  </div>]

# %%
soup.find_all('div', attrs = {'class':'map'})[0]
# Out:
# <div class="map">
# <img alt="Map" src="map.jpg"/>
# </div>

# %%
soup.find_all('div', attrs = {'class':'map'})[0].find_all('img')[0].attrs.get('src')
# Out:
# 'map.jpg'

# %%
# Objective : get the links in Related Links
soup.find_all('li')
# Out:
# [<li><a href="#">Home</a></li>,
#  <li><a href="#">About</a></li>,
#  <li><a href="#">Services</a></li>,
#  <li><a href="#">Contact</a></li>,
#  <li>Service 1</li>,
#  <li>Service 2</li>,
#  <li>Service 3</li>,
#  <li><a href="#" target="_blank">Link 1</a></li>,
#  <li><a href="#" target="_blank">Link 2</a></li>,
#  <li><a href="#" target="_blank">Link 3</a></li>]

# %%
soup.find_all('li')[7:]
# Out:
# [<li><a href="#" target="_blank">Link 1</a></li>,
#  <li><a href="#" target="_blank">Link 2</a></li>,
#  <li><a href="#" target="_blank">Link 3</a></li>]

# %%
<li><a href="#" target="_blank">Link 1</a></li>

# %%
soup.find_all('li')[-3].find_all('a')[0]['href']
# Out:
# '#'

# %%
soup.find_all('li')[-3].find_all('a')[0].text
# Out:
# 'Link 1'

# %%
for i in soup.find_all('li')[-3:]:
  print(i.find_all('a')[0]['href'])
# Out:
# #
# #
# #

# %%
href_list = []
for i in soup.find_all('li')[-3:]:
  href_list.append(i.find_all('a')[0]['href'])

# %%
# href_list
# Out:
# ['#', '#', '#']

# %%
# loc and iloc : Dataframe || pandas
# []: Indexing and slicing concept :

# %%
soup.find_all('h2')
# Out:
# [<h2>About Us</h2>,
#  <h2>Our Services</h2>,
#  <h2>Featured Products</h2>,
#  <h2>Contact Us</h2>,
#  <h2>Related Links</h2>,
#  <h2>Latest News</h2>,
#  <h2>Company Location</h2>]

# %%
# Example 1
soup.find_all('header')
# Out:
# [<header class="container">
#  <h1>Welcome to My Website</h1>
#  <nav>
#  <ul>
#  <li><a href="#">Home</a></li>
#  <li><a href="#">About</a></li>
#  <li><a href="#">Services</a></li>
#  <li><a href="#">Contact</a></li>
#  </ul>
#  </nav>
#  </header>]

# %%
# Example 2
soup.find_all('table',attrs={'class': 'news-table'})
# Out:
# [<tr>
#  <th>Date</th>
#  <th>Title</th>
#  <th>Category</th>
#  </tr>,
#  <tr>
#  <td>2024-05-01</td>
#  <td>News 1</td>
#  <td>General</td>
#  </tr>,
#  <tr>
#  <td>2024-05-02</td>
#  <td>News 2</td>
#  <td>Technology</td>
#  </tr>]

# %%
# Example 3
soup.find_all('a')
# Out:
# [<a href="#">Home</a>,
#  <a href="#">About</a>,
#  <a href="#">Services</a>,
#  <a href="#">Contact</a>,
#  <a class="button" href="#">Add to Cart</a>,
#  <a class="button" href="#">Add to Cart</a>,
#  <a href="#" target="_blank">Link 1</a>,
#  <a href="#" target="_blank">Link 2</a>,
#  <a href="#" target="_blank">Link 3</a>]

# %% [markdown]
# ### Scraping Table From the web

# %%
# Specifying the URL from which movies related data will be fetched
url='https://www.loc.gov/standards/iso639-2/php/code_list.php'

# Sending an HTTP GET request to the URL
page=requests.get(url)
# Parsing the HTML content using BeautifulSoup with the 'html.parser'
soup=BeautifulSoup(page.text,'html.parser')
# Printing the prettified HTML content
# print(soup.prettify())
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN"
#      "http://www.w3.org/TR/html40/loose.dtd">
# <html>
#  <!-- #BeginTemplate "/Templates/iso639-2.dwt" -->
#  <!-- DW6 -->
#  <head>
#   <!-- #BeginEditable "doctitle" -->
#   <title>
#    ISO 639-2 Language Code List - Codes for the representation of names of languages (Library of Congress)
#   </title>
#   <meta content="This document contains the ISO 639-2 Alpha-3
# codes for the representation of names of languages" name="description"/>
#   <meta content="ISO 639-2, language codes, alpha-3 codes, alpha-2 codes,
# bibliographic codes, terminology codes" name="keywords"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <link href="../iso639-2.css" rel="stylesheet" type="text/css"/>
#   <!-- #EndEditable -->
#   <script src="//assets.adobedtm.com/dac62e20b491e735c6b56e64c39134d8ee93f9cf/satelliteLib-6b47f831c184878d7338d4683ecf773a17973bb9.js">
#   </script>
#  </head>
# ...

# %%
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN"
#      "http://www.w3.org/TR/html40/loose.dtd">
#
# <html><!-- #BeginTemplate "/Templates/iso639-2.dwt" --><!-- DW6 -->
# <head>
# <!-- #BeginEditable "doctitle" -->
# <title>ISO 639-2 Language Code List - Codes for the representation of names of languages (Library of Congress)</title>
# <meta content="This document contains the ISO 639-2 Alpha-3
# codes for the representation of names of languages" name="description"/>
# <meta content="ISO 639-2, language codes, alpha-3 codes, alpha-2 codes,
# bibliographic codes, terminology codes" name="keywords"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="../iso639-2.css" rel="stylesheet" type="text/css"/>
# <!-- #EndEditable -->
# <script src="//assets.adobedtm.com/dac62e20b491e735c6b56e64c39134d8ee93f9cf/satelliteLib-6b47f831c184878d7338d4683ecf773a17973bb9.js"></script>
# </head>
# ...

# %%
# Objective : To get the table as a dataframe

# %%
soup.find_all('tr')
# Out:
# [<tr>
#  <td><!-- #BeginLibraryItem "/Library/iso639-2menu.lbi" --><p class="menu"><a href="//www.loc.gov/standards/iso639-2/">HOME</a> - <a href="http://www.infoterm.info/standardization/iso_639_1_2002.php">ISO
#          639-1 Registration Authority Home</a> <img alt="External Link" height="10" src="//www.loc.gov/images/icon-ext2.gif" width="8"/> - <a href="http://www.sil.org/iso639-3/">ISO 639-3 Registration Authority Home</a> <img alt="External Link" height="10" src="//www.loc.gov/images/icon-ext2.gif" width="8"/><br/>
#  <a href="http://www.sil.org/iso639-3/"></a><a href="http://www.sil.org/iso639-3/"> </a> <a href="../iso639jac.html">ISO 639 Joint Advisory Committee Home</a> - <a href="//www.loc.gov/standards/iso639-5/">ISO 639-5 Registration Authority Home</a></p>
#  <!-- #EndLibraryItem --><hr/>
#  <!-- #BeginEditable "content" -->
#  <h1>Codes for the Representation of Names of Languages</h1>
#  <h2>Codes arranged alphabetically by alpha-3/ISO 639-2  Code</h2>
# ...

# %%
soup.find_all('table',attrs = {'width':'100%'})
# Out:
# [<table border="1" cellpadding="4" cellspacing="0" width="100%">
#  <tr bgcolor="#ffffee" valign="top">
#  <th scope="col" width="15%">ISO 639-2 Code</th>
#  <th scope="col" width="15%">ISO 639-1 Code</th>
#  <th scope="col" width="20%">English name of Language</th>
#  <th scope="col" width="25%">French name of Language</th>
#  <th scope="col" width="25%">German name of Language</th>
#  </tr><tr valign="top">
#  <td scope="row">aar</td>
#  <td>aa</td>
#  <td>Afar</td>
#  <td>afar</td>
#  <td>Danakil-Sprache</td>
#  </tr><tr valign="top">
#  <td scope="row">abk</td>
#  <td>ab</td>
#  <td>Abkhazian</td>
#  <td>abkhaze</td>
#  <td>Abchasisch</td>
#  </tr><tr valign="top">
#  <td scope="row">ace</td>
#  <td> </td>
#  <td>Achinese</td>
#  <td>aceh</td>
#  <td>Aceh-Sprache</td>
#  </tr><tr valign="top">
#  <td scope="row">ach</td>
#  <td> </td>
#  <td>Acoli</td>
#  <td>acoli</td>
#  <td>Acholi-Sprache</td>
#  </tr><tr valign="top">
#  <td scope="row">ada</td>
#  <td> </td>
# ...

# %%
table_info = soup.find_all('table',attrs = {'width':'100%'})[0].find_all('tr')

# %%
# table_info

# %%
table_info[0].find_all('th')[0].text
# Out:
# 'ISO 639-2 Code'

# %%
columns = []
for i in table_info[0].find_all('th'):
  columns.append(i.text)

# %%
columns
# Out:
# ['ISO 639-2 Code',
#  'ISO 639-1 Code',
#  'English name of Language',
#  'French name of Language',
#  'German name of Language']

# %%
# List of list

# %%
table_full_data = []
for d in table_info[1:]:
  table_row_data = []
  for i in d.find_all('td'):
    table_row_data.append(i.text)
  table_full_data.append(table_row_data)

# %%
website_data = pd.DataFrame(table_full_data, columns = columns)

# %%
website_data.shape
# Out:
# (507, 5)

# %% [markdown]
# ### Scraping Movie URL's, Movie Title, release Year,Genres,IMBD,Runtime/Duration,Age Rating,Production Countries

# %%
# Specifying the URL from which movies related data will be fetched
url='https://www.justwatch.com/in/movies?release_year_from=2013'

# Sending an HTTP GET request to the URL
page=requests.get(url)
# Parsing the HTML content using BeautifulSoup with the 'html.parser'
soup=BeautifulSoup(page.text,'html.parser')
# Printing the prettified HTML content
# print(soup.prettify())
# Links
soup.find_all('a', attrs = {'class':'title-list-grid__item--link'})[0]['href']
list_link = []
for i in soup.find_all('a', attrs = {'class':'title-list-grid__item--link'}):
  list_link.append('https://www.justwatch.com'+i['href'])

# %%
# Out:
# '/in/movie/laapataa-ladies'

# %%
# Out:
# 'https://www.justwatch.com/in/movie/laapataa-ladies'

# %%
# Specifying the URL from which movies related data will be fetched
url = 'https://www.justwatch.com/in/movie/crakk-jeetegaa-toh-jiyegaa'

# Sending an HTTP GET request to the URL
page=requests.get(url)
# Parsing the HTML content using BeautifulSoup with the 'html.parser'
soup=BeautifulSoup(page.text,'html.parser')
soup.find_all('div', attrs = {'data-testid':'titleBlock'})

# %%
# print(soup.prettify())

# %%
soup.find_all('div', attrs = {'data-testid':'titleBlock'})
# Out:
# [<div data-testid="titleBlock"><h1> Crakk: Jeetega... Toh Jiyegaa </h1><span class="text-muted"> (2024) </span></div>]

# %%
# Movie Title
soup.find_all('div', attrs = {'data-testid':'titleBlock'})[0].find_all('h1')[0].text.strip()
# Out:
# 'Crakk: Jeetega... Toh Jiyegaa'

# %%
soup.find_all('div', attrs = {'data-testid':'titleBlock'})[0]
# Out:
# <div data-testid="titleBlock"><h1> Laapataa Ladies </h1><span class="text-muted"> (2024) </span></div>

# %%
# Release year
eval(soup.find_all('div', attrs = {'data-testid':'titleBlock'})[0].find_all('span')[0].text.strip())
# Out:
# 2024

# %%
# '(2024)' --> (2024) is it tuple? --> Int
# (2024,) --> tuple

# %%
# Imdb Rating
eval(soup.find_all('div',attrs = {'class':'detail-infos'})[0].find_all('span')[0].text.strip().split(' ')[0])
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-188-fd6ce8247c33>", line 2, in <cell line: 2>
#     eval(soup.find_all('div',attrs = {'class':'detail-infos'})[0].find_all('span')[0].text.strip().split(' ')[0])
#
#   File "<string>", line unknown
#
#     ^
# SyntaxError: invalid syntax

# %%
# soup.find_all('div',attrs = {'class':'detail-infos'})

# %%
info_dict = {}
for i in soup.find_all('div',attrs = {'class':'detail-infos'}):
  if i.find_all('h3', attrs = {'class':'detail-infos__subheading'})[0].text =='Genres':
    info_dict['Genres'] = i.find_all('div', attrs = {'class':'detail-infos__value'})[0].text.strip()
  elif i.find_all('h3', attrs = {'class':'detail-infos__subheading'})[0].text =='Runtime':
    info_dict['Runtime'] = i.find_all('div', attrs = {'class':'detail-infos__value'})[0].text.strip()
  elif i.find_all('h3', attrs = {'class':'detail-infos__subheading'})[0].text =='Age rating':
    info_dict['Age_rating'] = i.find_all('div', attrs = {'class':'detail-infos__value'})[0].text.strip()
  elif i.find_all('h3', attrs = {'class':'detail-infos__subheading'})[0].text.strip() =='Production country':
    info_dict['Production_country'] = i.find_all('div', attrs = {'class':'detail-infos__value'})[0].text.strip()

# %%
# info_dict
# Out:
# {'Genres': 'Action & Adventure, Mystery & Thriller, Sport',
#  'Runtime': '2h 34min',
#  'Age_rating': 'UA',
#  'Production_country': 'India'}

# %%
# list_link

# %%
import time
time.sleep(2)

# %%
movie_info_full_data = []
for l in list_link:
  info_dict = {}
  # Specifying the URL from which movies related data will be fetched
  url = l
  # Sending an HTTP GET request to the URL
  page=requests.get(url)
  # Parsing the HTML content using BeautifulSoup with the 'html.parser'
  soup=BeautifulSoup(page.text,'html.parser')
  try:
    info_dict['link'] = l
    info_dict['title'] = soup.find_all('div', attrs = {'data-testid':'titleBlock'})[0].find_all('h1')[0].text.strip()
    info_dict['release_year'] = eval(soup.find_all('div', attrs = {'data-testid':'titleBlock'})[0].find_all('span')[0].text.strip())
    # info_dict['imdb'] = eval(soup.find_all('div',attrs = {'class':'detail-infos'})[1].find_all('span')[0].text.strip().split(' ')[0])
    for i in soup.find_all('div',attrs = {'class':'detail-infos'}):
      if i.find_all('h3', attrs = {'class':'detail-infos__subheading'})[0].text =='Genres':
        info_dict['Genres'] = i.find_all('div', attrs = {'class':'detail-infos__value'})[0].text.strip()
      elif i.find_all('h3', attrs = {'class':'detail-infos__subheading'})[0].text =='Runtime':
        info_dict['Runtime'] = i.find_all('div', attrs = {'class':'detail-infos__value'})[0].text.strip()
      elif i.find_all('h3', attrs = {'class':'detail-infos__subheading'})[0].text =='Age rating':
        info_dict['Age_rating'] = i.find_all('div', attrs = {'class':'detail-infos__value'})[0].text.strip()
      elif i.find_all('h3', attrs = {'class':'detail-infos__subheading'})[0].text.strip() =='Production country':
        info_dict['Production_country'] = i.find_all('div', attrs = {'class':'detail-infos__value'})[0].text.strip()

    movie_info_full_data.append(info_dict)
    print('Successful:',l)
  except:
    print('Error:',l)
    continue

  time.sleep(2)

movie_dataframe = pd.DataFrame(movie_info_full_data)
# Out:
# Successfull: https://www.justwatch.com/in/movie/laapataa-ladies
# Successfull: https://www.justwatch.com/in/movie/article-370
# Successfull: https://www.justwatch.com/in/movie/premalu
# Successfull: https://www.justwatch.com/in/movie/dune-part-two
# Successfull: https://www.justwatch.com/in/movie/manjummel-boys
# Successfull: https://www.justwatch.com/in/movie/black-magic-2024
# Successfull: https://www.justwatch.com/in/movie/family-star
# Successfull: https://www.justwatch.com/in/movie/untitled-shahid-kapoor-kriti-sanon-film
# Successfull: https://www.justwatch.com/in/movie/amar-singh-chamkila
# Successfull: https://www.justwatch.com/in/movie/oppenheimer
# Successfull: https://www.justwatch.com/in/movie/the-crew-2024
# Successfull: https://www.justwatch.com/in/movie/hanu-man
# Successfull: https://www.justwatch.com/in/movie/anyone-but-you
# Successfull: https://www.justwatch.com/in/movie/yodha-2022
# Successfull: https://www.justwatch.com/in/movie/kung-fu-panda-4
# ...

# %%
# Out:
#                                                  link  \
# 0   https://www.justwatch.com/in/movie/laapataa-la...
# 1      https://www.justwatch.com/in/movie/article-370
# 2          https://www.justwatch.com/in/movie/premalu
# 3    https://www.justwatch.com/in/movie/dune-part-two
# 4   https://www.justwatch.com/in/movie/manjummel-boys
# ..                                                ...
# 90  https://www.justwatch.com/in/movie/rocky-aur-r...
# 91  https://www.justwatch.com/in/movie/war-for-the...
# 92  https://www.justwatch.com/in/movie/the-wolf-of...
# 93      https://www.justwatch.com/in/movie/the-intern
# 94           https://www.justwatch.com/in/movie/dunki
#
#                               title  release_year  \
# 0                   Laapataa Ladies          2024
# 1                       Article 370          2024
# 2                           Premalu          2024
# 3                    Dune: Part Two          2024
# 4                    Manjummel Boys          2024
# ...

# %% [markdown]
# ### File management command in python

# %%
# Writing to a file
with open('example.txt', 'w') as file:
    file.write('Hello, world!\n')
    file.write('This is a test file1.\n')

# %%
# append to a file
with open('example.txt', 'a') as file:
    file.write('Hello, world!\n')
    file.write('This is a test file1.\n')

# %%
# Reading from a file
with open('example.txt', 'r') as file:
    contents = file.read()
print(contents)
# Out:
# Hello, world!
# This is a test file1.
# Hello, world!
# This is a test file1.
# Hello, world!
# This is a test file1.
# Hello, world!
# This is a test file1.
# Hello, world!
# This is a test file1.

# %%
# CSV file
import csv

# Data to be written to the CSV file
data_to_write = [
    ['Name', 'Age', 'City'],
    ['John', 30, 'New York'],
    ['Alice', 25, 'Los Angeles'],
    ['Bob', 35, 'Chicago']
]

# Define the path to your CSV file
file_path = 'output.csv'

# Write data to the CSV file
with open(file_path, 'w') as file:
    writer = csv.writer(file)
    writer.writerows(data_to_write)

print("Data has been written to", file_path)
# Out:
# Data has been written to output.csv

# %%
with open(file_path, 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Age', 'City']
# ['John', '30', 'New York']
# ['Alice', '25', 'Los Angeles']
# ['Bob', '35', 'Chicago']
